# %%
from pathlib import Path
import pygimli as pg  # Stelle sicher, dass das Modul pg importiert ist und verfügbar ist
from pygimli.physics import ert
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from datetime import datetime
import os
import numpy as np
import matplotlib.colors as mcolors
import matplotlib.ticker as ticker
import matplotlib.ticker as mticker

from Hilfsfunktionen import T_corr_nach_Inversion
from Hilfsfunktionen import plotting_function
from Hilfsfunktionen import plotting_function_FTL

# Read data
file = "all_timesteps.ohm"
base_dir = Path("filtered_data")
data = []
for unterordner in base_dir.iterdir():
    if unterordner.is_dir():
        datei_pfad = unterordner / "all_timesteps.ohm" 
        if datei_pfad.exists():
            daten_objekt = pg.load(str(datei_pfad))
            data.append([unterordner.name, daten_objekt])
            print(f"Load data: {datei_pfad}")

# Create method manager
manager = []
for ts in data:
    manager.append(ert.ERTManager(ts[1], verbose=True))
# Out:
# Load data: filtered_data\240710\two_timesteps_240710_240808.ohm
# Load data: filtered_data\240808\two_timesteps_240710_240808.ohm
# 30/04/25 - 08:48:56 - pyGIMLi - INFO - Found 2 regions.
# 30/04/25 - 08:48:56 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 30/04/25 - 08:48:56 - pyGIMLi - INFO - Found 2 regions.
# 30/04/25 - 08:48:56 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 30/04/25 - 08:48:56 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 30/04/25 - 08:48:57 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 30/04/25 - 08:48:57 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 8540 Cells: 16788 Boundaries: 12736
# 30/04/25 - 08:48:57 - pyGIMLi - INFO - Use median(data values)=2043.9
# 30/04/25 - 08:48:57 - pyGIMLi - INFO - Created startmodel from forward operator: 3104, min/max=2043.900000/2043.900000
# 30/04/25 - 08:48:57 - pyGIMLi - INFO - Starting inversion.
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x000002196077A7A0>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x00000219CE74D7B0>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x000002197C0CC450>
# min/max (data): 65.6/6396
# min/max (error): 3%/3.02%
# min/max (start model): 2044/2044
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² = 1125.22
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =   34.58 (dPhi = 96.25%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =   25.73 (dPhi = 24.95%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =   20.02 (dPhi = 21.34%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... chi² =   15.96 (dPhi = 19.22%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... chi² =   12.82 (dPhi = 18.37%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 6 ... chi² =   10.41 (dPhi = 17.14%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 7 ... chi² =    8.35 (dPhi = 17.67%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 8 ... chi² =    6.47 (dPhi = 19.46%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 9 ... chi² =    4.45 (dPhi = 25.71%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 10 ... chi² =    1.51 (dPhi = 43.33%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 11 ... chi² =    1.40 (dPhi = 2.05%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 12 ...
# 30/04/25 - 08:56:21 - pyGIMLi - INFO - Found 2 regions.
# 30/04/25 - 08:56:21 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 30/04/25 - 08:56:21 - pyGIMLi - INFO - Found 2 regions.
# 30/04/25 - 08:56:21 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 30/04/25 - 08:56:21 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 30/04/25 - 08:56:21 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# chi² =    1.41 (dPhi = 0.03%) lam: 15.0
# ################################################################################
# #                Abort criterion reached: dPhi = 0.03 (< 0.1%)                 #
# ################################################################################
# 30/04/25 - 08:56:22 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 8540 Cells: 16788 Boundaries: 12736
# 30/04/25 - 08:56:22 - pyGIMLi - INFO - Starting inversion.
# 30/04/25 - 08:56:22 - pyGIMLi - INFO - Setting starting model as reference!
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x00000219CE5516C0>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x00000219D0EBCF90>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x00000219D158DB20>
# min/max (data): 75.9/5324
# min/max (error): 3%/3.01%
# min/max (start model): 13.74/9136
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² =   36.24
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =    1.02 (dPhi = 96.73%) lam: 10.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =    0.78 (dPhi = 19.90%) lam: 10.0
#
#
# ################################################################################
# #                  Abort criterion reached: chi² <= 1 (0.78)                   #
# ################################################################################
# T_Profil10_array_array_2024-07-10-11H_5.91e-07.npy
# T_Profil11_array_array_2024-08-08-09H_5.91e-07.npy
# 30/04/25 - 08:58:18 - pyGIMLi - INFO - Use median(data values)=1503.6685312339887
# 30/04/25 - 08:58:18 - pyGIMLi - INFO - Created startmodel from forward operator: 3104, min/max=1503.668531/1503.668531
# 30/04/25 - 08:58:18 - pyGIMLi - INFO - Starting inversion.
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x000002196077A7A0>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x00000219CE74D7B0>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x000002197C0CC450>
# min/max (data): 38.14/5121
# min/max (error): 3%/3.02%
# min/max (start model): 1504/1504
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² = 1235.40
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =   42.45 (dPhi = 95.90%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =   31.04 (dPhi = 26.26%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =   23.82 (dPhi = 22.49%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... chi² =   18.78 (dPhi = 20.13%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... chi² =   14.98 (dPhi = 18.97%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 6 ... chi² =   11.97 (dPhi = 18.47%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 7 ... chi² =    9.45 (dPhi = 18.92%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 8 ... chi² =    6.96 (dPhi = 22.96%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 9 ... chi² =    4.04 (dPhi = 32.67%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 10 ... chi² =    2.43 (dPhi = 22.31%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 11 ...
# 30/04/25 - 09:06:12 - pyGIMLi - INFO - Starting inversion.
# 30/04/25 - 09:06:12 - pyGIMLi - INFO - Setting starting model as reference!
# chi² =    2.43 (dPhi = 0.37%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 12 ... chi² =    2.44 (dPhi = 0.04%) lam: 15.0
# ################################################################################
# #                Abort criterion reached: dPhi = 0.04 (< 0.1%)                 #
# ################################################################################
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x00000219CE5516C0>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x00000219D0EBCF90>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x00000219D158DB20>
# min/max (data): 45.88/4403
# min/max (error): 3%/3.01%
# min/max (start model): 8.57/7317
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² =   33.00
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =    1.61 (dPhi = 94.49%) lam: 10.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =    1.35 (dPhi = 14.03%) lam: 10.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =    1.32 (dPhi = 1.84%) lam: 10.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... chi² =    1.32 (dPhi = 0.00%) lam: 10.0
# ################################################################################
# #                 Abort criterion reached: dPhi = 0.0 (< 0.1%)                 #
# ################################################################################
# Load data: filtered_data\240710\two_timesteps_240710_240808.ohm
# Load data: filtered_data\240808\two_timesteps_240710_240808.ohm
# 30/04/25 - 09:09:15 - pyGIMLi - INFO - Found 2 regions.
# 30/04/25 - 09:09:15 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 30/04/25 - 09:09:15 - pyGIMLi - INFO - Found 2 regions.
# 30/04/25 - 09:09:15 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 30/04/25 - 09:09:15 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 30/04/25 - 09:09:16 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 30/04/25 - 09:09:16 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 8540 Cells: 16788 Boundaries: 12736
# 30/04/25 - 09:09:16 - pyGIMLi - INFO - Use median(data values)=2043.9
# 30/04/25 - 09:09:16 - pyGIMLi - INFO - Created startmodel from forward operator: 3104, min/max=2043.900000/2043.900000
# 30/04/25 - 09:09:16 - pyGIMLi - INFO - Starting inversion.
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x000002196077A7A0>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x00000219CFF2DC60>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x000002196077A840>
# min/max (data): 65.6/6396
# min/max (error): 3%/3.02%
# min/max (start model): 2044/2044
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² = 1125.22
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =   34.58 (dPhi = 96.25%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =   25.74 (dPhi = 24.93%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =   20.03 (dPhi = 21.34%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... chi² =   15.97 (dPhi = 19.23%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... chi² =   12.82 (dPhi = 18.37%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 6 ... chi² =   10.41 (dPhi = 17.12%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 7 ... chi² =    8.35 (dPhi = 17.68%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 8 ... chi² =    6.47 (dPhi = 19.45%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 9 ... chi² =    4.45 (dPhi = 25.71%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 10 ... chi² =    1.51 (dPhi = 43.34%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 11 ... chi² =    1.40 (dPhi = 2.05%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 12 ... chi² =    1.41 (dPhi = 0.03%) lam: 15.0
# ################################################################################
# #                Abort criterion reached: dPhi = 0.03 (< 0.1%)                 #
# ################################################################################
# 30/04/25 - 09:17:10 - pyGIMLi - INFO - Found 2 regions.
# 30/04/25 - 09:17:10 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 30/04/25 - 09:17:10 - pyGIMLi - INFO - Found 2 regions.
# 30/04/25 - 09:17:10 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 30/04/25 - 09:17:10 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 30/04/25 - 09:17:10 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 30/04/25 - 09:17:11 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 8540 Cells: 16788 Boundaries: 12736
# 30/04/25 - 09:17:12 - pyGIMLi - INFO - Starting inversion.
# 30/04/25 - 09:17:12 - pyGIMLi - INFO - Setting starting model as reference!
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x00000219D0EBC6D0>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x00000219CFF40AE0>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x00000219D158F7E0>
# min/max (data): 75.9/5324
# min/max (error): 3%/3.01%
# min/max (start model): 13.74/9136
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² =   36.24
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =    1.17 (dPhi = 95.86%) lam: 50.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =    0.98 (dPhi = 11.44%) lam: 50.0
#
#
# ################################################################################
# #                  Abort criterion reached: chi² <= 1 (0.98)                   #
# ################################################################################
# T_Profil10_array_array_2024-07-10-11H_5.91e-07.npy
# T_Profil11_array_array_2024-08-08-09H_5.91e-07.npy
# T_Profil12_array_array_2024-09-05-12H_1.622e-06.npy
# T_Profil13_array_array_2024-10-01-10H_1.622e-06.npy
# 30/04/25 - 09:19:09 - pyGIMLi - INFO - Use median(data values)=1503.6685312339887
# 30/04/25 - 09:19:09 - pyGIMLi - INFO - Created startmodel from forward operator: 3104, min/max=1503.668531/1503.668531
# 30/04/25 - 09:19:09 - pyGIMLi - INFO - Starting inversion.
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x000002196077A7A0>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x00000219CFF2DC60>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x000002196077A840>
# min/max (data): 38.14/5121
# min/max (error): 3%/3.02%
# min/max (start model): 1504/1504
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² = 1235.40
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =   42.55 (dPhi = 95.89%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =   31.10 (dPhi = 26.30%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =   23.85 (dPhi = 22.50%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... chi² =   18.81 (dPhi = 20.14%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... chi² =   15.00 (dPhi = 18.98%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 6 ... chi² =   11.99 (dPhi = 18.47%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 7 ... chi² =    9.46 (dPhi = 18.93%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 8 ... chi² =    6.96 (dPhi = 22.99%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 9 ... chi² =    4.04 (dPhi = 32.67%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 10 ... chi² =    2.43 (dPhi = 22.35%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 11 ... chi² =    2.43 (dPhi = 0.37%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 12 ...
# 30/04/25 - 09:27:14 - pyGIMLi - INFO - Starting inversion.
# 30/04/25 - 09:27:14 - pyGIMLi - INFO - Setting starting model as reference!
# chi² =    2.44 (dPhi = 0.04%) lam: 15.0
# ################################################################################
# #                Abort criterion reached: dPhi = 0.04 (< 0.1%)                 #
# ################################################################################
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x00000219D0EBC6D0>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x00000219CFF40AE0>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x00000219D158F7E0>
# min/max (data): 45.88/4403
# min/max (error): 3%/3.01%
# min/max (start model): 8.57/7317
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² =   33.00
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =    1.80 (dPhi = 93.41%) lam: 50.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =    1.61 (dPhi = 7.99%) lam: 50.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =    1.61 (dPhi = 0.01%) lam: 50.0
# ################################################################################
# #                Abort criterion reached: dPhi = 0.01 (< 0.1%)                 #
# ################################################################################
# Load data: filtered_data\240710\two_timesteps_240710_240808.ohm
# Load data: filtered_data\240808\two_timesteps_240710_240808.ohm
# 30/04/25 - 09:28:48 - pyGIMLi - INFO - Found 2 regions.
# 30/04/25 - 09:28:48 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 30/04/25 - 09:28:48 - pyGIMLi - INFO - Found 2 regions.
# 30/04/25 - 09:28:48 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 30/04/25 - 09:28:48 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 30/04/25 - 09:28:48 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 30/04/25 - 09:28:49 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 8540 Cells: 16788 Boundaries: 12736
# 30/04/25 - 09:28:49 - pyGIMLi - INFO - Use median(data values)=2043.9
# 30/04/25 - 09:28:49 - pyGIMLi - INFO - Created startmodel from forward operator: 3104, min/max=2043.900000/2043.900000
# 30/04/25 - 09:28:49 - pyGIMLi - INFO - Starting inversion.
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x00000219D08E3380>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x00000219D158F060>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x0000021960412B10>
# min/max (data): 65.6/6396
# min/max (error): 3%/3.02%
# min/max (start model): 2044/2044
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² = 1125.22
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =   34.62 (dPhi = 96.25%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =   25.77 (dPhi = 24.91%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =   20.06 (dPhi = 21.32%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... chi² =   16.00 (dPhi = 19.21%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... chi² =   12.85 (dPhi = 18.36%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 6 ... chi² =   10.44 (dPhi = 17.12%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 7 ... chi² =    8.37 (dPhi = 17.67%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 8 ... chi² =    6.48 (dPhi = 19.47%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 9 ... chi² =    4.46 (dPhi = 25.77%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 10 ... chi² =    1.51 (dPhi = 43.38%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 11 ... chi² =    1.40 (dPhi = 2.07%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 12 ...
# 30/04/25 - 09:37:01 - pyGIMLi - INFO - Found 2 regions.
# 30/04/25 - 09:37:01 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 30/04/25 - 09:37:01 - pyGIMLi - INFO - Found 2 regions.
# 30/04/25 - 09:37:01 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 30/04/25 - 09:37:01 - pyGIMLi - INFO - Creating forward mesh from region infos.
# chi² =    1.41 (dPhi = 0.03%) lam: 15.0
# ################################################################################
# #                Abort criterion reached: dPhi = 0.03 (< 0.1%)                 #
# ################################################################################
# 30/04/25 - 09:37:02 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 30/04/25 - 09:37:02 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 8540 Cells: 16788 Boundaries: 12736
# 30/04/25 - 09:37:02 - pyGIMLi - INFO - Starting inversion.
# 30/04/25 - 09:37:02 - pyGIMLi - INFO - Setting starting model as reference!
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x000002197D94F650>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x00000219D0EBED90>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x00000219D156D3F0>
# min/max (data): 75.9/5324
# min/max (error): 3%/3.01%
# min/max (start model): 13.74/9136
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² =   36.24
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =    1.29 (dPhi = 95.09%) lam: 100.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =    1.10 (dPhi = 8.65%) lam: 100.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =    1.10 (dPhi = -0.00%) lam: 100.0
# ################################################################################
# #                Abort criterion reached: dPhi = -0.0 (< 0.1%)                 #
# ################################################################################
# T_Profil10_array_array_2024-07-10-11H_5.91e-07.npy
# T_Profil11_array_array_2024-08-08-09H_5.91e-07.npy
# T_Profil12_array_array_2024-09-05-12H_1.622e-06.npy
# T_Profil13_array_array_2024-10-01-10H_1.622e-06.npy
# T_Profil14_array_array_2024-10-30-11H_1.622e-06.npy
# 30/04/25 - 09:40:12 - pyGIMLi - INFO - Use median(data values)=1503.6685312339887
# 30/04/25 - 09:40:12 - pyGIMLi - INFO - Created startmodel from forward operator: 3104, min/max=1503.668531/1503.668531
# 30/04/25 - 09:40:12 - pyGIMLi - INFO - Starting inversion.
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x00000219D08E3380>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x00000219D158F060>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x0000021960412B10>
# min/max (data): 38.14/5121
# min/max (error): 3%/3.02%
# min/max (start model): 1504/1504
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² = 1235.40
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =   42.49 (dPhi = 95.90%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =   31.06 (dPhi = 26.29%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =   23.83 (dPhi = 22.49%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... chi² =   18.79 (dPhi = 20.14%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... chi² =   14.99 (dPhi = 18.96%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 6 ... chi² =   11.98 (dPhi = 18.46%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 7 ... chi² =    9.46 (dPhi = 18.93%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 8 ... chi² =    6.96 (dPhi = 22.98%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 9 ... chi² =    4.04 (dPhi = 32.66%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 10 ... chi² =    2.43 (dPhi = 22.34%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 11 ... chi² =    2.43 (dPhi = 0.37%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 12 ...
# 30/04/25 - 09:48:21 - pyGIMLi - INFO - Starting inversion.
# 30/04/25 - 09:48:21 - pyGIMLi - INFO - Setting starting model as reference!
# chi² =    2.44 (dPhi = 0.04%) lam: 15.0
# ################################################################################
# #                Abort criterion reached: dPhi = 0.04 (< 0.1%)                 #
# ################################################################################
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x000002197D94F650>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x00000219D0EBED90>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x00000219D156D3F0>
# min/max (data): 45.88/4403
# min/max (error): 3%/3.01%
# min/max (start model): 8.57/7317
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² =   33.00
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =    1.94 (dPhi = 92.47%) lam: 100.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =    1.75 (dPhi = 6.09%) lam: 100.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =    1.75 (dPhi = 0.00%) lam: 100.0
# ################################################################################
# #                 Abort criterion reached: dPhi = 0.0 (< 0.1%)                 #
# ################################################################################
# Load data: filtered_data\240710\two_timesteps_240710_240808.ohm
# Load data: filtered_data\240808\two_timesteps_240710_240808.ohm
# 30/04/25 - 09:50:11 - pyGIMLi - INFO - Found 2 regions.
# 30/04/25 - 09:50:11 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 30/04/25 - 09:50:11 - pyGIMLi - INFO - Found 2 regions.
# 30/04/25 - 09:50:11 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 30/04/25 - 09:50:11 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 30/04/25 - 09:50:11 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 30/04/25 - 09:50:12 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 8540 Cells: 16788 Boundaries: 12736
# 30/04/25 - 09:50:12 - pyGIMLi - INFO - Use median(data values)=2043.9
# 30/04/25 - 09:50:12 - pyGIMLi - INFO - Created startmodel from forward operator: 3104, min/max=2043.900000/2043.900000
# 30/04/25 - 09:50:12 - pyGIMLi - INFO - Starting inversion.
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x00000219D01BA160>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x00000219CFF41170>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x000002196077AB10>
# min/max (data): 65.6/6396
# min/max (error): 3%/3.02%
# min/max (start model): 2044/2044
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² = 1125.22
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =   34.56 (dPhi = 96.26%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =   25.73 (dPhi = 24.92%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =   20.03 (dPhi = 21.33%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... chi² =   15.97 (dPhi = 19.21%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... chi² =   12.82 (dPhi = 18.37%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 6 ... chi² =   10.41 (dPhi = 17.15%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 7 ... chi² =    8.35 (dPhi = 17.67%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 8 ... chi² =    6.47 (dPhi = 19.43%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 9 ... chi² =    4.45 (dPhi = 25.72%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 10 ... chi² =    1.51 (dPhi = 43.34%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 11 ... chi² =    1.40 (dPhi = 2.05%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 12 ... chi² =    1.41 (dPhi = 0.03%) lam: 15.0
# ################################################################################
# #                Abort criterion reached: dPhi = 0.03 (< 0.1%)                 #
# ################################################################################
# 30/04/25 - 09:57:06 - pyGIMLi - INFO - Found 2 regions.
# 30/04/25 - 09:57:06 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 30/04/25 - 09:57:06 - pyGIMLi - INFO - Found 2 regions.
# 30/04/25 - 09:57:06 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 30/04/25 - 09:57:06 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 30/04/25 - 09:57:06 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 30/04/25 - 09:57:07 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 8540 Cells: 16788 Boundaries: 12736
# 30/04/25 - 09:57:07 - pyGIMLi - INFO - Starting inversion.
# 30/04/25 - 09:57:07 - pyGIMLi - INFO - Setting starting model as reference!
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x00000219CFF43BA0>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x00000219CFF41CB0>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x00000219D01BBFB0>
# min/max (data): 75.9/5324
# min/max (error): 3%/3.01%
# min/max (start model): 13.74/9136
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² =   36.24
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =    1.45 (dPhi = 93.88%) lam: 200.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =    1.27 (dPhi = 6.15%) lam: 200.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =    1.27 (dPhi = -0.00%) lam: 200.0
# ################################################################################
# #                Abort criterion reached: dPhi = -0.0 (< 0.1%)                 #
# ################################################################################
# T_Profil10_array_array_2024-07-10-11H_5.91e-07.npy
# T_Profil11_array_array_2024-08-08-09H_5.91e-07.npy
# T_Profil12_array_array_2024-09-05-12H_1.622e-06.npy
# T_Profil13_array_array_2024-10-01-10H_1.622e-06.npy
# T_Profil14_array_array_2024-10-30-11H_1.622e-06.npy
# 30/04/25 - 09:59:28 - pyGIMLi - INFO - Use median(data values)=1503.6685312339887
# 30/04/25 - 09:59:29 - pyGIMLi - INFO - Created startmodel from forward operator: 3104, min/max=1503.668531/1503.668531
# 30/04/25 - 09:59:29 - pyGIMLi - INFO - Starting inversion.
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x00000219D01BA160>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x00000219CFF41170>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x000002196077AB10>
# min/max (data): 38.14/5121
# min/max (error): 3%/3.02%
# min/max (start model): 1504/1504
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² = 1235.40
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =   42.50 (dPhi = 95.89%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =   31.10 (dPhi = 26.23%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =   23.85 (dPhi = 22.51%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... chi² =   18.80 (dPhi = 20.16%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... chi² =   15.00 (dPhi = 18.97%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 6 ... chi² =   11.99 (dPhi = 18.47%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 7 ... chi² =    9.46 (dPhi = 18.92%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 8 ... chi² =    6.96 (dPhi = 22.99%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 9 ... chi² =    4.04 (dPhi = 32.71%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 10 ... chi² =    2.43 (dPhi = 22.31%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 11 ...
# 30/04/25 - 10:05:59 - pyGIMLi - INFO - Starting inversion.
# 30/04/25 - 10:05:59 - pyGIMLi - INFO - Setting starting model as reference!
# chi² =    2.43 (dPhi = 0.37%) lam: 15.0
# --------------------------------------------------------------------------------
# inv.iter 12 ... chi² =    2.44 (dPhi = 0.04%) lam: 15.0
# ################################################################################
# #                Abort criterion reached: dPhi = 0.04 (< 0.1%)                 #
# ################################################################################
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x00000219CFF43BA0>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x00000219CFF41CB0>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x00000219D01BBFB0>
# min/max (data): 45.88/4403
# min/max (error): 3%/3.01%
# min/max (start model): 8.57/7317
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² =   33.00
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =    2.12 (dPhi = 91.03%) lam: 200.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =    1.95 (dPhi = 4.37%) lam: 200.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =    1.95 (dPhi = 0.00%) lam: 200.0
# ################################################################################
# #                 Abort criterion reached: dPhi = 0.0 (< 0.1%)                 #
# ################################################################################

# %%
# Ergebnis-Container für alle Indizes
chi2_dict = {}
phi_m_dict = {}
phi_d_dict = {}
rms_dict = {}
rrms_dict = {}

# Für alle Indizes in manager
for idx in range(len(manager)):
    chi2_dict[idx] = []
    phi_m_dict[idx] = []
    phi_d_dict[idx] = []
    rms_dict[idx] = []
    rrms_dict[idx] = []
    
    for lam in lam_list:
        manager[idx].invert(
            quality=34,
            paraMaxCellSize=0.5,
            maxIter=20,
            dPhi=0.1,
            paraDepth=15,
            lam=lam
        )
        chi2_dict[idx].append(manager[idx].inv.chi2())
        phi_d_dict[idx].append(manager[idx].inv.phiData())
        phi_m_dict[idx].append(manager[idx].inv.phiModel())
        rrms_dict[idx].append(round(manager[idx].inv.relrms(), 2))
        rms_dict[idx].append(round(manager[idx].inv.absrms(), 2))

# %%
# alle Kurven plotten
for i in range(len(manager)):
    plt.plot(phi_m_dict[i], phi_d_dict[i], color='grey', marker='o', alpha=0.5)

# Mittelwerte berechnen
phi_m_mean = np.mean([phi_m_dict[i] for i in range(len(manager))], axis=0)
phi_d_mean = np.mean([phi_d_dict[i] for i in range(len(manager))], axis=0)

# Mittelkurve als Linie
plt.plot(phi_m_mean, phi_d_mean, color='red', linewidth=2, label='Mean L-curve')

# Punkte der Mittelkurve einfärben nach lam_list
sc = plt.scatter(phi_m_mean, phi_d_mean, 
                 c=lam_list,                # Werte für die Farbskala
                 cmap='jet',
                 norm=mcolors.LogNorm(vmin=min(lam_list), vmax=max(lam_list)),  # LOG-Skala# Colormap (z.B. plasma, inferno, jet, etc.)
                 s=60,                      # Punktgröße
                 edgecolor='black',         # optional: schwarze Umrandung
                 zorder=3)

# Farbskala hinzufügen
cbar = plt.colorbar(sc)
cbar.set_label("λ (Lambda)")

num_ticks = 6  
tick_values = np.logspace(np.log10(min(lam_list)), np.log10(max(lam_list)), num=num_ticks)
cbar.locator = mticker.FixedLocator(tick_values)
cbar.ax.set_yticklabels([f"{val:.3g}" for val in tick_values])  # formatieren, z.B. 3 sign. Stellen
cbar.ax.minorticks_off()

# Achsenbeschriftung und Titel
plt.xlabel("Model roughness Φₘ")
plt.ylabel("Data misfit Φ_d (χ²)")
plt.title("L-curve")
plt.legend()
plt.show()
