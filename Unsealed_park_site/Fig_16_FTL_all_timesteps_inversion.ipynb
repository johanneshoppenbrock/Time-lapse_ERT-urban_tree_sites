# %%
from pathlib import Path
import pygimli as pg  # Stelle sicher, dass das Modul pg importiert ist und verfügbar ist
from pygimli.physics import ert
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from datetime import datetime
import os
import numpy as np

from Hilfsfunktionen import T_corr_nach_Inversion
from Hilfsfunktionen import plotting_function
from Hilfsfunktionen import plotting_function_FTL

# Read data
file = "all_timesteps.ohm"
base_dir = Path("filtered_data")
data = []
for unterordner in base_dir.iterdir():
    if unterordner.is_dir():
        datei_pfad = unterordner / "all_timesteps.ohm" 
        if datei_pfad.exists():
            daten_objekt = pg.load(str(datei_pfad))
            data.append([unterordner.name, daten_objekt])
            print(f"Load data: {datei_pfad}")

# Create method manager
manager = []
for ts in data:
    manager.append(ert.ERTManager(ts[1], verbose=True))

# Create mesh
mesh = manager[0].createMesh(quality = 34, paraMaxCellSize=0.5, paraDepth=15)
manager[0].invert(quality = 34, paraMaxCellSize=0.5, maxIter=1 ,dPhi= 0.1, paraDepth=15,lam=20)

# Inversion without temperature correction
DATA = [dat[1] for dat in data]
# Full time-lapse
scalef = 0.8#0.8
fop = pg.frameworks.MultiFrameModelling(ert.ERTModelling, scalef=scalef)
fop.setData(DATA)
fop.setMesh(mesh)
print(fop.mesh()) 
dataVec = np.concatenate([data["rhoa"] for data in DATA])
errorVec = np.concatenate([data["err"] for data in DATA])
startModel = fop.createStartModel(dataVec)
inv = pg.Inversion(fop=fop, startModel=startModel, verbose=True)
model = inv.run(dataVec, errorVec, maxIter=10, lam= 12, startModel=startModel, verbose=True)
chi2 = []
rrms = []
chi2.append(round(inv.chi2(),2))
rrms.append(round(inv.relrms(),2))
mod = np.reshape(model, [len(DATA), -1])

# PLot
plotting_function_FTL(data,manager = manager, results = mod, folder_name= 'Result_all_timesteps', filename= 'all_timesteps_without_Tcorr', chi2=chi2, scalef=scalef, rrms=rrms)
plotting_function_FTL(data,manager = manager, results = mod, folder_name= 'Result_all_timesteps', filename= 'all_timesteps_without_Tcorr', chi2=chi2, scalef=scalef, rrms=rrms)

# Temperature correction    
ort_2 = 'Georg-Westermann-Park'
mod_corr = []
temp_spread = []
timestep = 0
mesh2 = manager[0].mesh.createSubMesh(manager[0].mesh.cells(manager[0].mesh.cellMarkers() == 2))
for count, m in enumerate(mod):
    timestep = count
    dateien = os.listdir(r".\Temperature_data/" + ort_2 )
    for datei in dateien: 
        if (datei).startswith('T_Profil%s_array' % (str(timestep))):
            print(datei)
            Temp_tiefe_vektor = np.load(r'.\Temperature_data/%s/' % (ort_2) + datei, allow_pickle=True)
    res_new,Tem_new = T_corr_nach_Inversion(m, mesh2, Temp_tiefe_vektor)
    mod_corr.append(res_new)
    temp_spread.append(Tem_new)

modell2 = np.reshape(mod, -1)
modell_corr = np.reshape(mod_corr, -1)
response = inv.fop.response(modell2)
response_t_corr = inv.fop.response(modell_corr)
difference = response_t_corr - response
diff = np.reshape(difference, [len(DATA), -1])
for h in range(len(diff)):
    DATA[h]['rhoa'] = DATA[h]['rhoa'] + diff[h]
    
    
# Inversion with temperature correction
# Full time-lapse
scalef = 0.8
fop = pg.frameworks.MultiFrameModelling(ert.ERTModelling, scalef=scalef)
fop.setData(DATA)
#manager[0].createMesh(quality=34,paraMaxCellSize=20)
fop.setMesh(mesh)
print(fop.mesh())  # important to call mesh() function once!
dataVec = np.concatenate([data["rhoa"] for data in DATA])
errorVec = np.concatenate([data["err"] for data in DATA])
startModel = fop.createStartModel(dataVec)
inv = pg.Inversion(fop=fop, startModel=startModel, verbose=True)
model = inv.run(dataVec, errorVec, maxIter=10, lam= 12, startModel=startModel, verbose=True)
chi2 = []
rrms = []
chi2.append(round(inv.chi2(),2))
rrms.append(round(inv.relrms(),2))
kw = dict(cMin=10, cMax=300, logScale=True, cMap="jet")
pd = fop.paraDomain
mod_Tcorr = np.reshape(model, [len(DATA), -1])

# Plot 
plotting_function_FTL(data, manager = manager,results = mod_Tcorr, folder_name= 'Result_all_timesteps', filename= 'all_timesteps_with_Tcorr_new', chi2=chi2, scalef=scalef, rrms = rrms)
# Out:
# Load data: filtered_data\230711\all_timesteps.ohm
# Load data: filtered_data\230809\all_timesteps.ohm
# Load data: filtered_data\231108\all_timesteps.ohm
# Load data: filtered_data\231211\all_timesteps.ohm
# Load data: filtered_data\240131\all_timesteps.ohm
# Load data: filtered_data\240306\all_timesteps.ohm
# Load data: filtered_data\240411\all_timesteps.ohm
# Load data: filtered_data\240510\all_timesteps.ohm
# Load data: filtered_data\240612\all_timesteps.ohm
# Load data: filtered_data\240705\all_timesteps.ohm
# Load data: filtered_data\240710\all_timesteps.ohm
# Load data: filtered_data\240808\all_timesteps.ohm
# Load data: filtered_data\240905\all_timesteps.ohm
# Load data: filtered_data\241001\all_timesteps.ohm
# Load data: filtered_data\241030\all_timesteps.ohm
# 06/11/25 - 23:18:55 - pyGIMLi - INFO - Found 2 regions.
# 06/11/25 - 23:18:55 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 06/11/25 - 23:18:55 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 06/11/25 - 23:18:55 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 06/11/25 - 23:18:55 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 8540 Cells: 16788 Boundaries: 12736
# 06/11/25 - 23:18:55 - pyGIMLi - INFO - Use median(data values)=1813.88
# 06/11/25 - 23:18:55 - pyGIMLi - INFO - Created startmodel from forward operator: 3104, min/max=1813.880000/1813.880000
# 06/11/25 - 23:18:55 - pyGIMLi - INFO - Starting inversion.
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x0000023EB55309A0>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x0000023EB0863420>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x0000023EB0A7BCE0>
# min/max (data): 162/6438
# min/max (error): 6.41%/6.41%
# min/max (start model): 1814/1814
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² =  134.76
# --------------------------------------------------------------------------------
# inv.iter 1 ...
# 06/11/25 - 23:19:26 - pyGIMLi - INFO - Found 2 regions.
# 06/11/25 - 23:19:26 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 06/11/25 - 23:19:26 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 06/11/25 - 23:19:26 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# chi² =    4.96 (dPhi = 94.62%) lam: 20.0
# 06/11/25 - 23:19:27 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 8540 Cells: 16788 Boundaries: 12736
# 3104 model cells
# Mesh: Nodes: 8540 Cells: 16788 Boundaries: 12736
# 06/11/25 - 23:20:13 - pyGIMLi - INFO - Starting inversion.
# fop: <pygimli.frameworks.timelapse.MultiFrameModelling object at 0x0000023EB302CFE0>
# Data transformation: <pgcore._pygimli_.RTrans object at 0x0000023F68AD37D0>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x0000023EB9FBB060>
# min/max (data): 54.97/9420
# min/max (error): 1.84%/6.43%
# min/max (start model): 1951/1951
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² = 8216.24
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =  298.91 (dPhi = 96.31%) lam: 12.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =   40.38 (dPhi = 85.71%) lam: 12.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =    2.19 (dPhi = 87.95%) lam: 12.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... chi² =    1.09 (dPhi = 24.15%) lam: 12.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... chi² =    1.00 (dPhi = 4.41%) lam: 12.0
#
#
# ################################################################################
# #                  Abort criterion reached: chi² <= 1 (1.00)                   #
# ################################################################################
# T_Profil0_array_array_2023-08-02-12H_1.709e-06.npy
# T_Profil1_array_array_2023-08-09-13H_1.709e-06.npy
# T_Profil2_array_array_2023-11-08-10H_1.709e-06.npy
# T_Profil3_array_array_2023-12-11-13H_1.709e-06.npy
# T_Profil4_array_array_2024-01-31-15H_9.19e-07.npy
# T_Profil5_array_array_2024-03-06-12H_9.19e-07.npy
# T_Profil6_array_array_2024-04-11-15H_9.19e-07.npy
# T_Profil7_array_array_2024-05-10-12H_6.26e-07_vonAllee.npy
# T_Profil8_array_array_2024-06-12-11H_4.95e-07.npy
# T_Profil9_array_array_2024-06-24-16H_4.95e-07.npy
# T_Profil10_array_array_2024-07-10-11H_5.91e-07.npy
# T_Profil11_array_array_2024-08-08-09H_5.91e-07.npy
# T_Profil12_array_array_2024-09-05-12H_1.622e-06.npy
# T_Profil13_array_array_2024-10-01-10H_1.622e-06.npy
# T_Profil14_array_array_2024-10-30-11H_1.622e-06.npy
# 07/11/25 - 00:03:56 - pyGIMLi - INFO - Found 2 regions.
# 07/11/25 - 00:03:56 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 07/11/25 - 00:03:56 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 07/11/25 - 00:03:57 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 07/11/25 - 00:03:58 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 8540 Cells: 16788 Boundaries: 12736
# 3104 model cells
# Mesh: Nodes: 8540 Cells: 16788 Boundaries: 12736
# 07/11/25 - 00:04:48 - pyGIMLi - INFO - Starting inversion.
# fop: <pygimli.frameworks.timelapse.MultiFrameModelling object at 0x0000023EBCF73560>
# Data transformation: <pgcore._pygimli_.RTrans object at 0x0000023EBD01ED50>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x0000023EC253AB60>
# min/max (data): 27.3/7515
# min/max (error): 1.84%/6.43%
# min/max (start model): 1277/1277
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² = 8852.51
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =  369.98 (dPhi = 95.77%) lam: 12.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =   48.80 (dPhi = 86.01%) lam: 12.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =    3.85 (dPhi = 85.38%) lam: 12.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... chi² =    2.07 (dPhi = 25.92%) lam: 12.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... chi² =    1.81 (dPhi = 6.33%) lam: 12.0
# --------------------------------------------------------------------------------
# inv.iter 6 ... chi² =    1.78 (dPhi = 1.60%) lam: 12.0
# ################################################################################
# #                 Abort criterion reached: dPhi = 1.6 (< 2.0%)                 #
# ################################################################################

# %%
np.save(r'C:\Users\johan\Nextcloud\Promotion\Paper1\Paper_Repository\Unsealed park site\Result_all_timesteps\FTL/Result_FTL', mod_Tcorr)
pd.save(r'C:\Users\johan\Nextcloud\Promotion\Paper1\Paper_Repository\Unsealed park site\Result_all_timesteps\FTL/mesh_neu')
# Out:
# 1

# %%
# Plot for Figure 9 
plotting_function_FTL(data[1:3], manager = manager,results = mod_Tcorr[1:3], folder_name= 'Fig16', filename= '230809_231108', chi2=chi2, scalef=scalef, rrms = rrms)
